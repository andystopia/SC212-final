# %%
import polars as pl
from polars import col
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# API_NE.EXP.GNFS.CD_DS2_en_csv_v2_4683656.csv
# Metadata_Country_API_NE.EXP.GNFS.CD_DS2_en_csv_v2_4683656.csv
# Metadata_Indicator_API_NE.EXP.GNFS.CD_DS2_en_csv_v2_4683656.csv
# Untitled.ipynb

# %%
df = pl.read_csv("API_NE.EXP.GNFS.CD_DS2_en_csv_v2_4683656.csv", skip_rows=4)

# %%
df
# Out:
# shape: (266, 66)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬──────────┬─────────┬─────────┬─────────┐
# │ Country    ┆ Country    ┆ Indicator  ┆ Indicator  ┆ ... ┆ 2018     ┆ 2019    ┆ 2020    ┆ 2021    │
# │ Name       ┆ Code       ┆ Name       ┆ Code       ┆     ┆ ---      ┆ ---     ┆ ---     ┆ ---     │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆     ┆ str      ┆ str     ┆ str     ┆ str     │
# │ str        ┆ str        ┆ str        ┆ str        ┆     ┆          ┆         ┆         ┆         │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪══════════╪═════════╪═════════╪═════════╡
# │ Aruba      ┆ ABW        ┆ Exports of ┆ NE.EXP.GNF ┆ ... ┆ 23631284 ┆ 2468715 ┆ 1411731 ┆         │
# │            ┆            ┆ goods and  ┆ S.CD       ┆     ┆ 91.62011 ┆ 083.798 ┆ 843.575 ┆         │
# │            ┆            ┆ services   ┆            ┆     ┆          ┆ 88      ┆ 42      ┆         │
# ...

# %%
usable = df.columns[:4]
usable
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']

# %%
df_next = df.melt(id_vars=usable, variable_name="year").sort("Country Name")

# %%
df_next
# Out:
# shape: (16492, 6)
# ┌──────────────┬──────────────┬──────────────────────┬────────────────┬──────┬──────────────────┐
# │ Country Name ┆ Country Code ┆ Indicator Name       ┆ Indicator Code ┆ year ┆ value            │
# │ ---          ┆ ---          ┆ ---                  ┆ ---            ┆ ---  ┆ ---              │
# │ str          ┆ str          ┆ str                  ┆ str            ┆ str  ┆ str              │
# ╞══════════════╪══════════════╪══════════════════════╪════════════════╪══════╪══════════════════╡
# │ Afghanistan  ┆ AFG          ┆ Exports of goods and ┆ NE.EXP.GNFS.CD ┆ 1960 ┆ 22222233.3333333 │
# │              ┆              ┆ services (c...       ┆                ┆      ┆                  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Afghanistan  ┆ AFG          ┆ Exports of goods and ┆ NE.EXP.GNFS.CD ┆ 1961 ┆ 24444455.5555556 │
# ...
